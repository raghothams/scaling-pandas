# %%
import pandas as pd

# %%
from pandas_help import colour_dtype

# %%
# !pwd
# Out:
# /Users/sanganichaitanya/Downloads/Pers/workshop/pandas-tutorial

# %%
trips_data = pd.read_csv("datasets/biketrip.csv")

# %%
trips_data.head()
# Out:
#      id  duration       start_date        start_station_name  \
# 0  4576      63.0  8/29/2013 14:13  South Van Ness at Market
# 1  4607      70.0  8/29/2013 14:42        San Jose City Hall
# 2  4130      71.0  8/29/2013 10:16   Mountain View City Hall
# 3  4251      77.0  8/29/2013 11:29        San Jose City Hall
# 4  4299      83.0  8/29/2013 12:02  South Van Ness at Market
#
#    start_station_id         end_date          end_station_name  \
# 0                66  8/29/2013 14:14  South Van Ness at Market
# 1                10  8/29/2013 14:43        San Jose City Hall
# 2                27  8/29/2013 10:17   Mountain View City Hall
# 3                10  8/29/2013 11:30        San Jose City Hall
# 4                66  8/29/2013 12:04            Market at 10th
#
#    end_station_id  bike_id subscription_type zip_code
# 0              66      520        Subscriber      NaN
# 1              10      661        Subscriber    95138
# 2              27       48        Subscriber    97214
# 3              10       26        Subscriber    95060
# 4              67      319        Subscriber    94103

# %%
trips_data.head().style.applymap(colour_dtype)
# Out:
# <style  type="text/css" >
#     #T_c3f49e0c_b200_11e8_b62c_6a0003471c90row0_col0 {
#             background-color:  red;
#         }    #T_c3f49e0c_b200_11e8_b62c_6a0003471c90row0_col1 {
#             background-color:  green;
#         }    #T_c3f49e0c_b200_11e8_b62c_6a0003471c90row0_col2 {
#             background-color:  orange;
#         }    #T_c3f49e0c_b200_11e8_b62c_6a0003471c90row0_col3 {
#             background-color:  orange;
#         }    #T_c3f49e0c_b200_11e8_b62c_6a0003471c90row0_col4 {
#             background-color:  red;
#         }    #T_c3f49e0c_b200_11e8_b62c_6a0003471c90row0_col5 {
#             background-color:  orange;
#         }    #T_c3f49e0c_b200_11e8_b62c_6a0003471c90row0_col6 {
#             background-color:  orange;
#         }    #T_c3f49e0c_b200_11e8_b62c_6a0003471c90row0_col7 {
#             background-color:  red;
#         }    #T_c3f49e0c_b200_11e8_b62c_6a0003471c90row0_col8 {
#             background-color:  red;
#         }    #T_c3f49e0c_b200_11e8_b62c_6a0003471c90row0_col9 {
#             background-color:  orange;
#         }    #T_c3f49e0c_b200_11e8_b62c_6a0003471c90row0_col10 {
#             background-color:  green;
#         }    #T_c3f49e0c_b200_11e8_b62c_6a0003471c90row1_col0 {
#             background-color:  red;
#         }    #T_c3f49e0c_b200_11e8_b62c_6a0003471c90row1_col1 {
#             background-color:  green;
#         }    #T_c3f49e0c_b200_11e8_b62c_6a0003471c90row1_col2 {
#             background-color:  orange;
#         }    #T_c3f49e0c_b200_11e8_b62c_6a0003471c90row1_col3 {
#             background-color:  orange;
#         }    #T_c3f49e0c_b200_11e8_b62c_6a0003471c90row1_col4 {
#             background-color:  red;
#         }    #T_c3f49e0c_b200_11e8_b62c_6a0003471c90row1_col5 {
#             background-color:  orange;
#         }    #T_c3f49e0c_b200_11e8_b62c_6a0003471c90row1_col6 {
#             background-color:  orange;
#         }    #T_c3f49e0c_b200_11e8_b62c_6a0003471c90row1_col7 {
#             background-color:  red;
#         }    #T_c3f49e0c_b200_11e8_b62c_6a0003471c90row1_col8 {
#             background-color:  red;
#         }    #T_c3f49e0c_b200_11e8_b62c_6a0003471c90row1_col9 {
#             background-color:  orange;
#         }    #T_c3f49e0c_b200_11e8_b62c_6a0003471c90row1_col10 {
#             background-color:  orange;
#         }    #T_c3f49e0c_b200_11e8_b62c_6a0003471c90row2_col0 {
#             background-color:  red;
#         }    #T_c3f49e0c_b200_11e8_b62c_6a0003471c90row2_col1 {
#             background-color:  green;
#         }    #T_c3f49e0c_b200_11e8_b62c_6a0003471c90row2_col2 {
#             background-color:  orange;
#         }    #T_c3f49e0c_b200_11e8_b62c_6a0003471c90row2_col3 {
#             background-color:  orange;
#         }    #T_c3f49e0c_b200_11e8_b62c_6a0003471c90row2_col4 {
#             background-color:  red;
#         }    #T_c3f49e0c_b200_11e8_b62c_6a0003471c90row2_col5 {
#             background-color:  orange;
#         }    #T_c3f49e0c_b200_11e8_b62c_6a0003471c90row2_col6 {
#             background-color:  orange;
#         }    #T_c3f49e0c_b200_11e8_b62c_6a0003471c90row2_col7 {
#             background-color:  red;
#         }    #T_c3f49e0c_b200_11e8_b62c_6a0003471c90row2_col8 {
#             background-color:  red;
#         }    #T_c3f49e0c_b200_11e8_b62c_6a0003471c90row2_col9 {
#             background-color:  orange;
#         }    #T_c3f49e0c_b200_11e8_b62c_6a0003471c90row2_col10 {
#             background-color:  orange;
#         }    #T_c3f49e0c_b200_11e8_b62c_6a0003471c90row3_col0 {
#             background-color:  red;
#         }    #T_c3f49e0c_b200_11e8_b62c_6a0003471c90row3_col1 {
#             background-color:  green;
#         }    #T_c3f49e0c_b200_11e8_b62c_6a0003471c90row3_col2 {
#             background-color:  orange;
#         }    #T_c3f49e0c_b200_11e8_b62c_6a0003471c90row3_col3 {
#             background-color:  orange;
#         }    #T_c3f49e0c_b200_11e8_b62c_6a0003471c90row3_col4 {
#             background-color:  red;
#         }    #T_c3f49e0c_b200_11e8_b62c_6a0003471c90row3_col5 {
#             background-color:  orange;
#         }    #T_c3f49e0c_b200_11e8_b62c_6a0003471c90row3_col6 {
#             background-color:  orange;
#         }    #T_c3f49e0c_b200_11e8_b62c_6a0003471c90row3_col7 {
#             background-color:  red;
#         }    #T_c3f49e0c_b200_11e8_b62c_6a0003471c90row3_col8 {
#             background-color:  red;
#         }    #T_c3f49e0c_b200_11e8_b62c_6a0003471c90row3_col9 {
#             background-color:  orange;
#         }    #T_c3f49e0c_b200_11e8_b62c_6a0003471c90row3_col10 {
#             background-color:  orange;
#         }    #T_c3f49e0c_b200_11e8_b62c_6a0003471c90row4_col0 {
#             background-color:  red;
#         }    #T_c3f49e0c_b200_11e8_b62c_6a0003471c90row4_col1 {
#             background-color:  green;
#         }    #T_c3f49e0c_b200_11e8_b62c_6a0003471c90row4_col2 {
#             background-color:  orange;
#         }    #T_c3f49e0c_b200_11e8_b62c_6a0003471c90row4_col3 {
#             background-color:  orange;
#         }    #T_c3f49e0c_b200_11e8_b62c_6a0003471c90row4_col4 {
#             background-color:  red;
#         }    #T_c3f49e0c_b200_11e8_b62c_6a0003471c90row4_col5 {
#             background-color:  orange;
#         }    #T_c3f49e0c_b200_11e8_b62c_6a0003471c90row4_col6 {
#             background-color:  orange;
#         }    #T_c3f49e0c_b200_11e8_b62c_6a0003471c90row4_col7 {
#             background-color:  red;
#         }    #T_c3f49e0c_b200_11e8_b62c_6a0003471c90row4_col8 {
#             background-color:  red;
#         }    #T_c3f49e0c_b200_11e8_b62c_6a0003471c90row4_col9 {
#             background-color:  orange;
#         }    #T_c3f49e0c_b200_11e8_b62c_6a0003471c90row4_col10 {
#             background-color:  orange;
#         }</style>
# <table id="T_c3f49e0c_b200_11e8_b62c_6a0003471c90" >
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >id</th>
#         <th class="col_heading level0 col1" >duration</th>
#         <th class="col_heading level0 col2" >start_date</th>
#         <th class="col_heading level0 col3" >start_station_name</th>
#         <th class="col_heading level0 col4" >start_station_id</th>
#         <th class="col_heading level0 col5" >end_date</th>
#         <th class="col_heading level0 col6" >end_station_name</th>
#         <th class="col_heading level0 col7" >end_station_id</th>
#         <th class="col_heading level0 col8" >bike_id</th>
#         <th class="col_heading level0 col9" >subscription_type</th>
#         <th class="col_heading level0 col10" >zip_code</th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_c3f49e0c_b200_11e8_b62c_6a0003471c90level0_row0" class="row_heading level0 row0" >0</th>
#         <td id="T_c3f49e0c_b200_11e8_b62c_6a0003471c90row0_col0" class="data row0 col0" >4576</td>
#         <td id="T_c3f49e0c_b200_11e8_b62c_6a0003471c90row0_col1" class="data row0 col1" >63</td>
#         <td id="T_c3f49e0c_b200_11e8_b62c_6a0003471c90row0_col2" class="data row0 col2" >8/29/2013 14:13</td>
#         <td id="T_c3f49e0c_b200_11e8_b62c_6a0003471c90row0_col3" class="data row0 col3" >South Van Ness at Market</td>
#         <td id="T_c3f49e0c_b200_11e8_b62c_6a0003471c90row0_col4" class="data row0 col4" >66</td>
#         <td id="T_c3f49e0c_b200_11e8_b62c_6a0003471c90row0_col5" class="data row0 col5" >8/29/2013 14:14</td>
#         <td id="T_c3f49e0c_b200_11e8_b62c_6a0003471c90row0_col6" class="data row0 col6" >South Van Ness at Market</td>
#         <td id="T_c3f49e0c_b200_11e8_b62c_6a0003471c90row0_col7" class="data row0 col7" >66</td>
#         <td id="T_c3f49e0c_b200_11e8_b62c_6a0003471c90row0_col8" class="data row0 col8" >520</td>
#         <td id="T_c3f49e0c_b200_11e8_b62c_6a0003471c90row0_col9" class="data row0 col9" >Subscriber</td>
#         <td id="T_c3f49e0c_b200_11e8_b62c_6a0003471c90row0_col10" class="data row0 col10" >nan</td>
#     </tr>    <tr>
#         <th id="T_c3f49e0c_b200_11e8_b62c_6a0003471c90level0_row1" class="row_heading level0 row1" >1</th>
#         <td id="T_c3f49e0c_b200_11e8_b62c_6a0003471c90row1_col0" class="data row1 col0" >4607</td>
#         <td id="T

# %% [markdown]
# ### Memory usage of data frame
#
# Pandas stores the data on RAM by grouping same dtypes in blocks. This helps in optimising for storage and aceessing them quickly ( think of it like legos )
#
# <div class="row">
#   <div class="column">
#     <img src="datasets/int block.png" alt="alternate text" height = "120" width = "80" style="float: left; margin-left: 20%">
#   </div>
#   <div class="column">
#     <img src="datasets/float block.png" height = "30" width = "80" style="float: left;">
#   </div>
#   <div class="column">
#     <img src="datasets/object block.png" height = "300" width = "200" style="float: left;">
#   </div>
# </div>
#
# <br>
#
#
#
# The columns and row indices are missing here. **Block Manager** class of Pandas takes care of these mappings.
# This data is put on RAM for quick retrieval and computation, making it a challenge to work on medium/ large datasets.
#
# Hence optimizing for dtypes plays crucial role in improving performance and storage.

# %%
trips_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 669959 entries, 0 to 669958
# Data columns (total 11 columns):
# id                    669959 non-null int64
# duration              669930 non-null float64
# start_date            669959 non-null object
# start_station_name    669959 non-null object
# start_station_id      669959 non-null int64
# end_date              669959 non-null object
# end_station_name      669959 non-null object
# end_station_id        669959 non-null int64
# bike_id               669959 non-null int64
# subscription_type     669959 non-null object
# zip_code              661650 non-null object
# dtypes: float64(1), int64(4), object(6)
# memory usage: 56.2+ MB

# %%
trips_data.info(memory_usage="deep")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 669959 entries, 0 to 669958
# Data columns (total 11 columns):
# id                    669959 non-null int64
# duration              669930 non-null float64
# start_date            669959 non-null object
# start_station_name    669959 non-null object
# start_station_id      669959 non-null int64
# end_date              669959 non-null object
# end_station_name      669959 non-null object
# end_station_id        669959 non-null int64
# bike_id               669959 non-null int64
# subscription_type     669959 non-null object
# zip_code              661650 non-null object
# dtypes: float64(1), int64(4), object(6)
# memory usage: 303.2 MB

# %%
# Mean and total usage of each dtype

for dtype in ['float', 'int', 'object']:
    chosen_dtype = trips_data.select_dtypes(include=[dtype])
    col_num = chosen_dtype.shape[1]
    mean_usage_bytes = chosen_dtype.memory_usage(deep=True).mean()
    sum_usage_bytes = chosen_dtype.memory_usage(deep=True).sum()
    mean_usage_mb = mean_usage_bytes/1024**2
    sum_usage_mb = sum_usage_bytes/1024**2
    print("Average memory usage for {} {} column(s): {:03.2f} MB".format(col_num,dtype, mean_usage_mb))
    print("Total memory usage for {} {} column(s): {:03.2f} MB".format(col_num, dtype, sum_usage_mb))
# Out:
# Average memory usage for 1 float column(s): 2.56 MB
# Total memory usage for 1 float column(s): 5.11 MB
# Average memory usage for 4 int column(s): 4.09 MB
# Total memory usage for 4 int column(s): 20.45 MB
# Average memory usage for 6 object column(s): 39.66 MB
# Total memory usage for 6 object column(s): 277.61 MB

# %% [markdown]
# ### Optimizing Numeric Columns
#
# Integer and float dtypes are the numeric dtypes. There are sub dtypes of these based on the length and size of the dytpes.
#
# The numeric columns are stored as Numpy ndarray, which is based on C arrays. Hence they are stored as continuous block of memory and access to this data is pretty fast and accurate. To understand optimize dtypes, we need to understand the subtypes better.
#
# - Integer dtypes
#     - int8
#     - int16
#     - int32
#     - int64
#
# `int8` can hold values ranging from -128 to 127 (2^8 values for 8 bits)
#
# Similarly for float there are `float16`, `float32` and `float64`. The ```-ve``` sign in the integer dtypes occupies some memory. Using unsigned integer or `unit` solves this problem.
#
# Let's convert and optimize the int objects by `downcast`

# %%
# Lets create a function to calculate memory usage for objects

def get_mem_usage(obj):
    col_num = obj.shape[1]
    mean_usage_bytes = obj.memory_usage(deep=True).mean()
    sum_usage_bytes = obj.memory_usage(deep=True).sum()
    mean_usage_mb = mean_usage_bytes/1024**2
    sum_usage_mb = sum_usage_bytes/1024**2
    print("Average memory usage for {} column(s): {:03.2f} MB".format(col_num, mean_usage_mb))
    print("Total memory usage for {} column(s): {:03.2f} MB".format(col_num, sum_usage_mb))

# %%
# optimizing int objects

int_dtypes = trips_data.select_dtypes(include=['int'])

# %%
get_mem_usage(int_dtypes)
# Out:
# Average memory usage for 4 column(s): 4.09 MB
# Total memory usage for 4 column(s): 20.45 MB

# %%
optimized_int_dtypes = int_dtypes.apply(pd.to_numeric, downcast='unsigned')

# %%
get_mem_usage(optimized_int_dtypes)
# Out:
# Average memory usage for 4 column(s): 1.02 MB
# Total memory usage for 4 column(s): 5.11 MB

# %%
# Similarly optimizing float objects

float_dtypes = trips_data.select_dtypes(include=['float'])
get_mem_usage(float_dtypes)
# Out:
# Average memory usage for 1 column(s): 2.56 MB
# Total memory usage for 1 column(s): 5.11 MB

# %%
optimized_float_dtypes = float_dtypes.apply(pd.to_numeric, downcast='float')
get_mem_usage(optimized_float_dtypes)
# Out:
# Average memory usage for 1 column(s): 1.28 MB
# Total memory usage for 1 column(s): 2.56 MB

# %% [markdown]
# ### Optimizing Object dtypes
#
# Though we reduced the memory usage of numeric columns by 60%, majority is made up by string/ object dtype columns. To understand why these dtypes take up a lot of space as compared to numeric arrays, need to dig a little into how a Python works.
#
# A numpy array is a continuous block of memory with a single pointer to the array. While in case of Python List/ object class, it points to continuos block of pointers which in turn point to the data. This is because Python being high level intrepreted language, doesn't have a lot of control on memory mamanement and scatters the data on the memory.
#
# <img src="datasets/array_vs_list.png" height = "700" width = "550">
#
#
# With pointers, each taking up a byte of memory and variable sizes of each string, memory is used very inefficiently.
#
# Converting the categorical values to int saves a lot of memory and a lot of performance. With `.astype('category')` (introduced from pandas 0.15), the categorical values are converted to int values with a mapping dictionary.

# %%
object_dtypes = trips_data.select_dtypes(include=['object'])

# %%
object_dtypes
# Out:
#              start_date                             start_station_name  \
# 0       8/29/2013 14:13                       South Van Ness at Market
# 1       8/29/2013 14:42                             San Jose City Hall
# 2       8/29/2013 10:16                        Mountain View City Hall
# 3       8/29/2013 11:29                             San Jose City Hall
# 4       8/29/2013 12:02                       South Van Ness at Market
# 5       8/29/2013 18:54                            Golden Gate at Polk
# 6       8/29/2013 13:25                         Santa Clara at Almaden
# 7       8/29/2013 14:02                            San Salvador at 1st
# 8       8/29/2013 17:01                       South Van Ness at Market
# 9       8/29/2013 11:33                             San Jose City Hall
# 10      8/29/2013 13:52                                Spear at Folsom
# 11      8/29/2013 13:23                               San Pedro Square
# 12      8/29/2013 19:32                 Mountain View Caltrain Station
# 13      8/29/2013 13:57                              2nd at South Park
# 14      8/29/2013 12:31                                Clay at Battery
# 15      8/29/2013 16:57                                Post at Kearney
# 16      8/29/2013 11:25                             San Jose City Hall
# 17      8/29/2013 12:11                                 Market at 10th
# 18      8/29/2013 22:21                              Steuart at Market
# 19      8/29/2013 22:06                             Powell Street BART
# 20      8/29/2013 19:42                                Spear at Folsom
# 21      8/29/2013 12:45                  Redwood City Caltrain Station
# 22      8/29/2013 11:40                        San Francisco City Hall
# 23      8/29/2013 22:12                                Post at Kearney
# 24      8/29/2013 10:56                                Beale at Market
# 25      8/29/2013 13:53                                      Japantown
# 26      8/29/2013 13:43  Temporary Transbay Terminal (Howard at Beale)
# 27      8/29/2013 13:31                          San Jose Civic Center
# 28      8/29/2013 21:43                       South Van Ness at Market
# 29      8/29/2013 18:45                    Redwood City Medical Center
# ...                 ...                                            ...
# 669929    9/1/2014 9:30                                    Ryland Park
# 669930    9/1/2014 9:29                                  Market at 4th
# 669931    9/1/2014 9:29                                  Market at 4th
# 669932    9/1/2014 9:18                       South Van Ness at Market
# 669933    9/1/2014 9:16                                 Market at 10th
# 669934    9/1/2014 8:58                Grant Avenue at Columbus Avenue
# 669935    9/1/2014 8:55                  Powell at Post (Union Square)
# 669936    9/1/2014 8:55                  Powell at Post (Union Square)
# 669937    9/1/2014 8:49                                  Market at 4th
# 669938    9/1/2014 8:41                         Embarcadero at Vallejo
# 669939    9/1/2014 8:31                                  Market at 4th
# 669940    9/1/2014 8:31                                  Market at 4th
# 669941    9/1/2014 8:30                               Davis at Jackson
# 669942    9/1/2014 8:26                          Embarcadero at Bryant
# 669943    9/1/2014 8:24                                 Market at 10th
# 669944    9/1/2014 8:16                                 Post at Kearny
# 669945    9/1/2014 8:12                              Steuart at Market
# 669946    9/1/2014 8:11                          Embarcadero at Folsom
# 669947    9/1/2014 7:37                        Mountain View City Hall
# 669948    9/1/2014 7:37                        Mountain View City Hall
# 669949    9/1/2014 7:32                          Embarcadero at Bryant
# 669950    9/1/2014 7:03                                      Japantown
# 669951    9/1/2014 6:58                                 Market at 10th
# 669952    9/1/2014 5:54  Yerba Buena Center of the Arts (3rd @ Howard)
# 669953    9/1/2014 4:59                       South Van Ness at Market
# 669954    9/1/2014 4:21                             Powell Street BART
# 669955    9/1/2014 3:16           Harry Bridges Plaza (Ferry Building)
# 669956    9/1/2014 0:05                       South Van Ness at Market
# 669957    9/1/2014 0:05                       South Van Ness at Market
# 669958    9/1/2014 0:05                       South Van Ness at Market
#
#                end_date                          end_station_name  \
# 0       8/29/2013 14:14                  South Van Ness at Market
# 1       8/29/2013 14:43                        San Jose City Hall
# 2       8/29/2013 10:17                   Mountain View City Hall
# 3       8/29/2013 11:30                        San Jose City Hall
# 4       8/29/2013 12:04                            Market at 10th
# 5       8/29/2013 18:56                       Golden Gate at Polk
# 6       8/29/2013 13:27                          Adobe on Almaden
# 7       8/29/2013 14:04                       San Salvador at 1st
# 8       8/29/2013 17:03                  South Van Ness at Market
# 9       8/29/2013 11:35                               MLK Library
# 10      8/29/2013 13:55                     Embarcadero at Bryant
# 11      8/29/2013 13:25                    Santa Clara at Almaden
# 12      8/29/2013 19:35            Mountain View Caltrain Station
# 13      8/29/2013 13:59                         2nd at South Park
# 14      8/29/2013 12:33                           Beale at Market
# 15      8/29/2013 16:59                           Post at Kearney
# 16      8/29/2013 11:27                        San Jose City Hall
# 17      8/29/2013 12:14                            Market at 10th
# 18      8/29/2013 22:24      Harry Bridges Plaza (Ferry Building)
# 19      8/29/2013 22:08                             Market at 4th
# 20      8/29/2013 19:44                     Embarcadero at Bryant
# 21      8/29/2013 12:48             Redwood City Caltrain Station
# 22      8/29/2013 11:42                   San Francisco City Hall
# 23      8/29/2013 22:14                         Market at Sansome
# 24      8/29/2013 10:59                         Steuart at Market
# 25      8/29/2013 13:56                                 Japantown
# 26      8/29/2013 13:46                     Embarcadero at Folsom
# 27      8/29/2013 13:34                       San Salvador at 1st
# 28      8/29/2013 21:46                  South Van Ness at Market
# 29      8/29/2013 18:48                          Broadway at Main
# ...                 ...                                       ...
# 669929    9/1/2014 9:38                     San Jose Civic Center
# 669930   9/1/2014 16:05             Powell at Post (Union Square)
# 669931   9/1/2014 16:05             Powell at Post (Union Square)
# 669932    9/1/2014 9:29                         Market at Sansome
# 669933    9/1/2014 9:22                        Powell Street BART
# 669934    9/1/2014 9:05                             Howard at 2nd
# 669935   9/1/2014 11:00             Powell at Post (Union Square)
# 669936   9/1/2014 11:00             Powell at Post (Union Square)
# 669937    9/1/2014 8:54  San Francisco Caltrain (Townsend at 4th)
# 669938    9/1/2014 8:48                    Embarcadero at Sansome
# 669939    9/1/2014 8:57                    Embarcadero at Sansome
# 669940    9/1/2014 8:57                    Embarcadero at Sansome
# 669941    9/1/2014 8:52                          Davis at Jackson
# 669942    9/1/2014 8:36                    Embarcadero at Sansome
# 669943    9/1/2014 8:29                        Powell Street BART
# 669944   9/1/2014 10:12                         Market at Sansome
# 669945    9/1/2014 8:19                    Embarcadero at Sansome
# 669946    9/1/2014 8:14      Harry Bridges Plaza (Ferry Building)
# 669947   9/1/2014 12:27                   Mountain View City Hall
# 669948   9/1/2014 12:25                   Mountain View City Hall
# 669949    9/1/2014 7:35                     Embarcadero at Folsom
# 669950    9/1/2014 8:38                                 Japantown
# 669951    9/1/2014 7:05                         Market at Sansome
# 669952    9/1/2014 6:00                         Steuart at Market
# 669953    9/1/2014 5:03         Civic Center BART (7th at Market)
# 669954    9/1/2014 4:32                           Townsend at 7th
# 669955    9/1/2014 5:08  San Francisco Caltrain (Townsend at 4th)
# 669956    9/1/2014 0:14                             5th at Howard
# 669957    9/1/2014 0:15                             5th at Howard
# 669958    9/1/2014 0:15                             5th at Howard
#
#        subscription_type zip_code
# 0             Subscriber      NaN
# 1             Subscriber    95138
# 2             Subscriber    97214
# 3             Subscriber    95060
# 4             Subscriber    94103
# 5             Subscriber    94109
# 6             Subscriber    95112
# 7             Subscriber    95112
# 8             Subscriber    94103
# 9             Subscriber    95060
# 10            Subscriber    94109
# 11            Subscriber    95112
# 12            Subscriber    94041
# 13            Subscriber    94122
# 14            Subscriber    94109
# 15            Subscriber    94117
# 16            Subscriber    95060
# 17            Subscriber    94103
# 18            Subscriber    94115
# 19            Subscriber    94115
# 20            Subscriber    94105
# 21            Subscriber    94061
# 22            Subscriber    94110
# 23            Subscriber    94115
# 24              Customer    94117
# 25            Subscriber    95112
# 26            Subscriber    94109
# 27            Subscriber    95112
# 28            Subscriber    94115
# 29            Subscriber    94041
# ...                  ...      ...
# 669929        Subscriber     5112
# 669930          Customer    31100
# 669931          Customer    31100
# 669932        Subscriber    94103
# 669933        Subscriber    94107
# 669934        Subscriber    94133
# 669935          Customer      nil
# 669936          Customer      nil
# 669937        Subscriber    94080
# 669938          Customer        1
# 669939          Customer      nil
# 669940          Customer      nil
# 669941        Subscriber    94111
# 669942        Subscriber    94105
# 669943        Subscriber    94103
# 669944          Customer      nil
# 669945        Subscriber    94066
# 669946        Subscriber    94105
# 669947          Customer    94085
# 669948          Customer    94085
# 669949        Subscriber    94105
# 669950          Customer    95112
# 669951        Subscriber    94132
# 669952        Subscriber    94112
# 669953        Subscriber    94102
# 669954        Subscriber    94118
# 669955          Customer    44100
# 669956          Customer       32
# 669957          Customer       32
# 669958          Customer       32
#
# [669959 rows x 6 columns]

# %%
# Start station, end station and subscription type, zip code are categorical variables

object_dtypes_cat = object_dtypes[['start_station_name', 'end_station_name', 'subscription_type', 'zip_code']]

# %%
get_mem_usage(object_dtypes_cat)
# Out:
# Average memory usage for 4 column(s): 37.22 MB
# Total memory usage for 4 column(s): 186.09 MB

# %%
optimized_object_dtypes_cat = pd.DataFrame()
for column in object_dtypes_cat.columns:
    optimized_object_dtypes_cat[column] = object_dtypes_cat[column].astype('category')

# %%
get_mem_usage(optimized_object_dtypes_cat)
# Out:
# Average memory usage for 4 column(s): 0.79 MB
# Total memory usage for 4 column(s): 3.96 MB

# %% [markdown]
# > The string type datetime objects are converted to Python datetime objects (64 byte) because they ease the time series analysis.

# %%
object_dtypes_dates = object_dtypes[['start_date', 'end_date']]

# %%
get_mem_usage(object_dtypes_dates)
# Out:
# Average memory usage for 2 column(s): 30.51 MB
# Total memory usage for 2 column(s): 91.52 MB

# %%
optimized_object_dtypes_dates = pd.DataFrame()
for column in object_dtypes_dates.columns:
    print(column)
    optimized_object_dtypes_dates[column] = pd.to_datetime(object_dtypes_dates[column])
# Out:
# start_date
# end_date

# %%
get_mem_usage(optimized_object_dtypes_dates)
# Out:
# Average memory usage for 2 column(s): 3.41 MB
# Total memory usage for 2 column(s): 10.22 MB

# %%
# Lets do all the optimizations together
optimize_trips_data = trips_data.copy()

# %%
int_dtypes = optimize_trips_data.select_dtypes(include=['int'])
optimize_trips_data[int_dtypes.columns] = int_dtypes.apply(pd.to_numeric, downcast='unsigned')

# %%
float_dtypes = optimize_trips_data.select_dtypes(include=['float'])
optimize_trips_data[float_dtypes.columns] = float_dtypes.apply(pd.to_numeric, downcast='float')

# %%
cat_dtypes = optimize_trips_data[['start_station_name', 'end_station_name', 'subscription_type', 'zip_code']]

for col in cat_dtypes.columns:
    optimize_trips_data[col] = cat_dtypes[col].astype('category')

# %%
date_dtypes = optimize_trips_data[['start_date', 'end_date']]

# %%
for col in date_dtypes.columns:
    print(col)
    optimize_trips_data[col] = pd.to_datetime(date_dtypes[col])
# Out:
# start_date
# end_date

# %%
get_mem_usage(trips_data)
# Out:
# Average memory usage for 11 column(s): 25.26 MB
# Total memory usage for 11 column(s): 303.17 MB

# %%
get_mem_usage(optimize_trips_data)
# Out:
# Average memory usage for 11 column(s): 1.82 MB
# Total memory usage for 11 column(s): 21.85 MB

# %% [markdown]
# Reduced the size of the data frame by ~95%
