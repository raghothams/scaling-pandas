# %%
import pandas as pd

# %%
# !pwd
# Out:
# /Users/sanganichaitanya/Downloads/Pers/workshop/pandas-tutorial

# %% [markdown]
# ## Reading different file formats

# %%
trips_data = pd.read_csv("datasets/biketrip.csv")

# %%
trips_data
# Out:
#             id  duration       start_date  \
# 0         4576        63  8/29/2013 14:13
# 1         4607        70  8/29/2013 14:42
# 2         4130        71  8/29/2013 10:16
# 3         4251        77  8/29/2013 11:29
# 4         4299        83  8/29/2013 12:02
# 5         4927       103  8/29/2013 18:54
# 6         4500       109  8/29/2013 13:25
# 7         4563       111  8/29/2013 14:02
# 8         4760       113  8/29/2013 17:01
# 9         4258       114  8/29/2013 11:33
# 10        4549       125  8/29/2013 13:52
# 11        4498       126  8/29/2013 13:23
# 12        4965       129  8/29/2013 19:32
# 13        4557       130  8/29/2013 13:57
# 14        4386       134  8/29/2013 12:31
# 15        4749       138  8/29/2013 16:57
# 16        4242       141  8/29/2013 11:25
# 17        4329       142  8/29/2013 12:11
# 18        5097       142  8/29/2013 22:21
# 19        5084       144  8/29/2013 22:06
# 20        4982       146  8/29/2013 19:42
# ...

# %%
type(trips_data)
# Out:
# pandas.core.frame.DataFrame

# %%
top_trips_data = pd.read_json("../datasets/biketrip.json", orient = 'split')

# %%
type(top_trips_data)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# **Can checkout about all the arguements of the function like this**
# > ? pd.read_csv
#
# - Pandas can read from over **15 file formats** including html, sql and sas (try with tab)

# %% [markdown]
# ## Exploring the data

# %%
trips_data.head()
# Out:
#             id  duration        start_date           start_station_name  \
# 573566  568474  17270400   12/6/2014 21:59     South Van Ness at Market
# 382718  825850   2137000   6/28/2015 21:50            Market at Sansome
# 440339  750192   1852590     5/2/2015 6:17  San Antonio Shopping Center
# 371066  841176   1133540   7/10/2015 10:35       University and Emerson
# 80510   111309    722236  11/30/2013 13:29       University and Emerson
#
#         start_station_id         end_date  \
# 573566                66  6/24/2015 20:18
# 382718                77  7/23/2015 15:27
# 440339                31  5/23/2015 16:53
# 371066                35  7/23/2015 13:27
# 80510                 35  12/8/2013 22:06
#
#                                      end_station_name  end_station_id  \
# 573566                                  2nd at Folsom              62
# 382718  Yerba Buena Center of the Arts (3rd @ Howard)              68
# ...

# %%
trips_data.tail(10)
# Out:
#             id  duration        start_date  \
# 40000    57581        60  10/14/2013 14:47
# 597389  534343        60    11/7/2014 9:45
# 194364  362788        60   7/14/2014 14:09
# 633879  483333        60   10/4/2014 19:21
# 10457    18792        60   9/12/2013 10:09
# 326026  900176        60   8/21/2015 13:24
# 450401  736948        60   4/22/2015 17:47
# 72159   100171        60  11/18/2013 15:01
# 511423  652693        60   2/21/2015 12:45
# 2925      8651        60    9/2/2013 10:50
#
#                                    start_station_name  start_station_id  \
# 40000                                 Clay at Battery                41
# 597389  Temporary Transbay Terminal (Howard at Beale)                55
# 194364                             Powell Street BART                39
# 633879  Yerba Buena Center of the Arts (3rd @ Howard)                68
# 10457               Civic Center BART (7th at Market)                72
# ...

# %%
trips_data.shape # (rows, columns)
# Out:
# (669959, 11)

# %%
trips_data.describe()
# Out:
#                   id      duration  start_station_id  end_station_id  \
# count  669959.000000  6.699590e+05     669959.000000   669959.000000
# mean   460382.009899  1.107950e+03         57.851876       57.837438
# std    264584.458487  2.225544e+04         17.112474       17.200142
# min      4069.000000  6.000000e+01          2.000000        2.000000
# 25%    231082.500000  3.440000e+02         50.000000       50.000000
# 50%    459274.000000  5.170000e+02         62.000000       62.000000
# 75%    692601.000000  7.550000e+02         70.000000       70.000000
# max    913460.000000  1.727040e+07         84.000000       84.000000
#
#              bike_id
# count  669959.000000
# mean      427.587620
# std       153.450988
# min         9.000000
# 25%       334.000000
# 50%       440.000000
# 75%       546.000000
# max       878.000000

# %%
trips_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 669959 entries, 573566 to 2925
# Data columns (total 11 columns):
# id                    669959 non-null int64
# duration              669959 non-null int64
# start_date            669959 non-null object
# start_station_name    669959 non-null object
# start_station_id      669959 non-null int64
# end_date              669959 non-null object
# end_station_name      669959 non-null object
# end_station_id        669959 non-null int64
# bike_id               669959 non-null int64
# subscription_type     669959 non-null object
# zip_code              661650 non-null object
# dtypes: int64(5), object(6)
# memory usage: 61.3+ MB

# %%
trips_data['start_station_id'].unique()
# Out:
# array([66, 77, 31, 35, 22, 50, 14, 34,  3,  2, 36,  6, 29, 33, 28, 32, 26,
#         9, 76, 67, 42, 27, 39, 38, 73, 12, 41, 72,  5,  7, 47, 62, 56, 57,
#        58, 63, 37, 74, 60,  4, 75, 65, 71, 48, 10, 61, 55, 80, 51, 11, 54,
#        68, 16, 13, 49,  8, 83, 46, 70, 24, 45, 84, 69, 23, 64, 82, 30, 59,
#        25, 21])

# %%
trips_data['start_station_id'].unique().shape
# Out:
# (70,)

# %%
trips_data['start_station_id'].nunique()
# Out:
# 70

# %%
trips_data.dtypes # Note the dtypes mentioned - datetime objects will be dealt later
# Out:
# id                     int64
# duration               int64
# start_date            object
# start_station_name    object
# start_station_id       int64
# end_date              object
# end_station_name      object
# end_station_id         int64
# bike_id                int64
# subscription_type     object
# zip_code              object
# dtype: object

# %% [markdown]
# ## Summary
#
# - Reading from different formats
#
# - Exploring the data
#     - quantitative: Shape, head
#     - qualitative: info, describe, dtypes, unique, nunique

# %% [markdown]
# # Exercise

# %% [markdown]
# ### P01 Basics - Read the file '../datasets/food prices dataset.json' to variable trips_data

# %%
# %load "solutions/P01_Basics.py"

# %% [markdown]
# ### P02 Basics - How many rows in the Dataframe ?

# %%
# %load "solutions/P02_Basics.py"

# %% [markdown]
# ### P03 Basics - What is the mean duration of all the trips?

# %%
# %load "solutions/P03_Basics.py"

# %% [markdown]
# ### P04 Basics - How many bikes are there in total?

# %%
# %load "solutions/P04_Basics.py"

# %% [markdown]
# ### P05 Basics - How many null values are there in zip code?

# %%
# %load "solutions/P05_Basics.py"
